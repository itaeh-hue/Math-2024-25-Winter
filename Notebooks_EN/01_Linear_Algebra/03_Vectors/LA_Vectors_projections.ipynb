# %% [markdown]
# # Vectors - Projections and Divisions
#
#
# ## Projecting a Vector onto Another Vector
#
# Projecting vector $\mathbf{a}$ onto axis $\mathbf{b}$ involves finding the component of vector $\mathbf{a}$ along the direction of $\mathbf{b}$.
#
# Projection of $\mathbf{a}$ onto $\mathbf{b}$:
#
# $$
# \text{Proj}_{\mathbf{b}} \mathbf{a} = \frac{\mathbf{a} \cdot \mathbf{b}}{|\mathbf{b}|^2} \mathbf{b}
# $$
#
#
# ## Projecting a Vector onto Axes
#
# Projecting vector $\mathbf{a}$ onto an axis involves finding the component of vector $\mathbf{a}$ along that axis.
#
# Projection of $\mathbf{a}$ onto the $OX$ axis:
#
# $$
# \text{Proj}_{OX} \mathbf{a} = \frac{\mathbf{a} \cdot \mathbf{i}}{|\mathbf{i}|^2} \mathbf{i} = \frac{\mathbf{a} \cdot \mathbf{i}}{1} \mathbf{i} = (\mathbf{a} \cdot \mathbf{i}) \mathbf{i}
# $$
#
# Projection of $\mathbf{a}$ onto the $OY$ axis:
#
# $$
# \text{Proj}_{OY} \mathbf{a} = \frac{\mathbf{a} \cdot \mathbf{j}}{|\mathbf{j}|^2} \mathbf{j} = \frac{\mathbf{a} \cdot \mathbf{j}}{1} \mathbf{j} = (\mathbf{a} \cdot \mathbf{j}) \mathbf{j}
# $$
#
# Recall that $\mathbf{i} = (1, 0)$ and $\mathbf{j} = (0, 1)$ are unit vectors along the $OX$ and $OY$ axes.
#
#
# ## Dividing a Line Segment in a Given Ratio
#
# A line segment is defined by two points in space.
#
# Line segments and vectors are closely related because a line segment connecting two points can be treated as a vector directed from one point to another.
#
# If point \( P \) divides the line segment connecting points $A(x_1, y_1)$ and $B(x_2, y_2)$ in the ratio $m:n$, then the coordinates of point $P$ can be found using the formula:
#
# $$
# P = \left(\frac{n \times x_2 + m \times x_1}{m+n}, \frac{n \times y_2 + m \times y_1}{m+n}\right)
# $$
#
# **Example:**
#
# Given a line segment connecting points $A(1, 2)$ and $B(3, 8)$, find point $P$ that divides the segment in the ratio 2:3.
#
# Coordinates of point $P$:
# $$
# P = \left(\frac{2 \times 3 + 3 \times 1}{2+3}, \frac{2 \times 8 + 3 \times 2}{2+3}\right) = \left(\frac{9}{5}, \frac{22}{5}\right)
# $$

# %%
import matplotlib.pyplot as plt
import math

# Coordinates of points A and B
A = (1, 2)
B = (3, 8)

# Ratio m:n
m, n = 2, 3

# Calculate coordinates of point P that divides the segment in the ratio 2:3
P_x = (n * A[0] + m * B[0]) / (m + n)
P_y = (n * A[1] + m * B[1]) / (m + n)
P = (P_x, P_y)

# Plotting the graph
plt.figure(figsize=(6, 6))

# Plotting line segment AB
plt.plot([A[0], B[0]], [A[1], B[1]], 'k--', label='Line Segment AB')

# Marking points A, B, and P
plt.scatter(*A, color='blue', label='A(1, 2)')
plt.scatter(*B, color='red', label='B(3, 8)')
plt.scatter(*P, color='green', label=f'P({P[0]:.2f}, {P[1]:.2f})')

# Point labels
plt.text(A[0]-0.2, A[1], 'A(1, 2)', fontsize=12, color='blue')
plt.text(B[0]+0.1, B[1], 'B(3, 8)', fontsize=12, color='red')
plt.text(P[0]+0.1, P[1], f'P({P[0]:.2f}, {P[1]:.2f})', fontsize=12, color='green')

# Adding grid and axis labels
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Dividing a Line Segment in the Ratio 2:3')
plt.legend()

# Displaying the graph
plt.show()

# %% [raw]
# ---

# %% [markdown]
# ## Student Exercises
#
# - Divide the line segment connecting points $A(-1, 2)$ and $B(3, -2)$ in the ratio $1:3$. Illustrate the result on a graph.
#
# - Project vector $\mathbf{a} = (3, 4)$ onto the $OX$ and $OY$ axes. Illustrate the result on a graph.
#
# - Project vector $\mathbf{a} = (2,3)$ onto vector $\mathbf{b} = (1, 1)$. Illustrate the result on a graph.
#
# - Project vector $\mathbf{b} = (1, 1)$ onto vector $\mathbf{a} = (2, 3)$. Illustrate the result on a graph.

# %% [markdown]
# 1.
#
# If point $P$ divides the line segment connecting points $A(x_1, y_1)$ and $B(x_2, y_2)$ in the ratio $m:n$, then the coordinates of point $P$ can be found using the formula:
#
#
# $$P = \left(\frac{n \times x_2 + m \times x_1}{m+n}, \frac{n \times y_2 + m \times y_1}{m+n}\right)$$
#
#
# 1. First, we will find the coordinates $x$ and $y$ of the point dividing the line segment at a given ratio:
#
# $$x = \frac{n \times x_{2} + m \times x_{1}}{m+n} =
# \frac{3 \times 3 + 1 \times (-1)}{1 + 3} = \frac{9 -1}{4} = 2
# $$
#
#
# $$y = \frac{n \times y_{2} + m \times y_{1}}{m+n} =
# \frac{3 \times (-2) + 1 \times 2}{1 + 3} = \frac{-6 + 2}{4} = -1
# $$
#
# Therefore, the coordinates of the point dividing the line segment $d(A,B)$ are $(x,y) = (2,1)$.
#
#
# 2. Plotting the diagram...

# %%
import matplotlib.pyplot as plt
import math

# Coordinates of points A and B
A = (-1, 2)
B = (3, -2)

# Ratio m:n
m, n = 1, 3

# Calculate coordinates of point P that divides the segment in the ratio 2:3
P_x = (n * A[0] + m * B[0]) / (m + n)
P_y = (n * A[1] + m * B[1]) / (m + n)
P = (P_x, P_y)

# Plotting the graph
plt.figure(figsize=(6, 6))

# Plotting line segment AB
plt.plot([A[0], B[0]], [A[1], B[1]], 'k--', label='Line Segment AB')

# Marking points A, B, and P
plt.scatter(*A, color='blue', label='A(1, 2)')
plt.scatter(*B, color='red', label='B(3, 8)')
plt.scatter(*P, color='green', label=f'P({P[0]:.2f}, {P[1]:.2f})')

# Point labels
plt.text(A[0]-0.2, A[1], 'A(1, -2)', fontsize=12, color='blue')
plt.text(B[0]+0.1, B[1], 'B(3, -2)', fontsize=12, color='red')
plt.text(P[0]+0.1, P[1], f'P({P[0]:.2f}, {P[1]:.2f})', fontsize=12, color='green')

# Adding grid and axis labels
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Dividing a Line Segment in the Ratio 2:3')
plt.legend()

# Displaying the graph
plt.show()

# %% [markdown]
# 2. Projecting vector $\mathbf{a}$ onto an axis involves finding the component of vector $\mathbf{a}$ along that axis.
#
# Projection of $\mathbf{a} = (3,4)$ onto the $OX$ axis ($\mathbf{i} = (1,0)$):
#
# $$\text{Proj}_{OX} \mathbf{a} = \frac{\mathbf{a} \cdot \mathbf{i}}{|\mathbf{i}|^2} \mathbf{i} = \frac{\mathbf{a} \cdot \mathbf{i}}{1} \mathbf{i} = (\mathbf{a} \cdot \mathbf{i}) \mathbf{i} = ((3,4)\cdot(1,0))\mathbf{i} = (3\times1+4\times0)\mathbf{i}=(3,0)
# $$
#
#
#
# Projection of $\mathbf{a} = (3,4)$ onto the $OY$ axis ($\mathbf{j} = (0,1)$):
#
# $$\text{Proj}_{OY} \mathbf{a} = \frac{\mathbf{a} \cdot \mathbf{j}}{|\mathbf{j}|^2} \mathbf{j} = \frac{\mathbf{a} \cdot \mathbf{j}}{1} \mathbf{j} = (\mathbf{a} \cdot \mathbf{j}) \mathbf{j} = \mathbf{j}((3,4)\cdot(0,1)) = (3 \times 0 + 4 \times 1)\mathbf{j} = (0,4)
# $$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the original vector 'a'
a = np.array([3, 4])
proj_OX = np.array([3, 0])  # Projection onto the x-axis
proj_OY = np.array([0, 4])  # Projection onto the y-axis

# Create figure and axis
plt.figure(figsize=(8, 8))
ax = plt.gca()

# Set limits and aspect
ax.set_xlim(-1, 5)
ax.set_ylim(-1, 5)
ax.set_aspect('equal')

# Add grid
plt.grid()

# Plot the original vector
plt.quiver(0, 0, a[0], a[1], angles='xy', scale_units='xy', scale=1, color='blue', label='Vector a = (3, 4)')

# Plot the projections
plt.quiver(0, 0, proj_OX[0], proj_OX[1], angles='xy', scale_units='xy', scale=1, color='red', label='Projection onto OX')
plt.quiver(0, 0, proj_OY[0], proj_OY[1], angles='xy', scale_units='xy', scale=1, color='green', label='Projection onto OY')

# Mark the points of projection
plt.plot(proj_OX[0], proj_OX[1], 'ro')  # Point on OX
plt.plot(proj_OY[0], proj_OY[1], 'go')  # Point on OY

# Add labels to the projections
plt.text(proj_OX[0], proj_OX[1], ' P_OX', fontsize=12, color='red', verticalalignment='bottom')
plt.text(proj_OY[0], proj_OY[1], ' P_OY', fontsize=12, color='green', verticalalignment='bottom')

# Add title and legend
plt.title('Vector Projection onto OX and OY Axes')
plt.legend()
plt.axhline(0, color='black',linewidth=0.5, ls='--')
plt.axvline(0, color='black',linewidth=0.5, ls='--')

# Show the plot
plt.show()

# %% [markdown]
# 3.
# To project the vector $\mathbf{a} = (2, 3)$ onto the vector $\mathbf{b} = (1, 1)$, we can use the following projection formula:
#
# Projection of $\mathbf{a}$ onto $\mathbf{b}$:
#
# $$\text{Proj}_{\mathbf{b}} \mathbf{a} = \frac{\mathbf{a} \cdot \mathbf{b}}{|\mathbf{b}|^2} \mathbf{b} = \frac{(2,3)\cdot(1,1)}{(1,1)\cdot(1,1)}\mathbf{b} = \frac{2+3}{1+1}\mathbf{b}= \frac{5}{2}\mathbf{b} = \left( \frac{5}{2}, \frac{5}{2} \right) = (2.5, 2.5)
# $$
#
#
# $$
# \text{proj}_{\mathbf{b}} \mathbf{a} = \frac{5}{2} \mathbf{b} = \frac{5}{2} \begin{pmatrix} 1 \ 1 \end{pmatrix} = \begin{pmatrix} \frac{5}{2} \ \frac{5}{2} \end{pmatrix} = \left(2.5, 2.5\right)
# $$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define vectors a and b
a = np.array([2, 3])
b = np.array([1, 1])

# Calculate the projection of a onto b
dot_product_ab = np.dot(a, b)
dot_product_bb = np.dot(b, b)
proj_ab = (dot_product_ab / dot_product_bb) * b

# Create figure and axis
plt.figure(figsize=(8, 8))
ax = plt.gca()

# Set limits and aspect
ax.set_xlim(0, 3)
ax.set_ylim(0, 4)
ax.set_aspect('equal')

# Add grid
plt.grid()

# Plot the original vector a
plt.quiver(0, 0, a[0], a[1], angles='xy', scale_units='xy', scale=1, color='blue', label='Vector a = (2, 3)')

# Plot the projection of a onto b
plt.quiver(0, 0, proj_ab[0], proj_ab[1], angles='xy', scale_units='xy', scale=1, color='red', label='Projection of a onto b')

# Plot the vector b
plt.quiver(0, 0, b[0], b[1], angles='xy', scale_units='xy', scale=1, color='green', label='Vector b = (1, 1)')


# Mark the endpoint of the projection
plt.plot(proj_ab[0], proj_ab[1], 'ro')  # Point on the projection

# Add labels to the projection point
plt.text(proj_ab[0], proj_ab[1], ' P_{ab}', fontsize=12, color='red', verticalalignment='bottom')

# Add title and legend
plt.title('Vector Projection of a onto b')
plt.legend()
plt.axhline(0, color='black', linewidth=0.5, ls='--')
plt.axvline(0, color='black', linewidth=0.5, ls='--')

# Show the plot
plt.show()

# %% [markdown]
# 4.
# $$\text{Proj}_{\mathbf{a}} \mathbf{b} = \frac{\mathbf{b} \cdot \mathbf{a}}{|\mathbf{a}|^2} \mathbf{a} = \frac{(2,3)\cdot(1,1)}{(2,3)\cdot(2,3)}\mathbf{a} = \frac{2+3}{4+9}\mathbf{a} = \frac{5}{13}\mathbf{a} = \frac{5}{13}(2,3) = \left( \frac{10}{13}, \frac{15}{13} \right)
# $$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define vectors a and b
a = np.array([2, 3])
b = np.array([1, 1])

# Calculate the projection of b onto a
dot_product_ba = np.dot(b, a)
dot_product_aa = np.dot(a, a)
proj_ba = (dot_product_ba / dot_product_aa) * a

# Create figure and axis
plt.figure(figsize=(8, 8))
ax = plt.gca()

# Set limits and aspect
ax.set_xlim(0, 3)
ax.set_ylim(0, 4)
ax.set_aspect('equal')

# Add grid
plt.grid()

# Plot the original vector b
plt.quiver(0, 0, b[0], b[1], angles='xy', scale_units='xy', scale=1, color='green', label='Vector b = (1, 1)')

# Plot the vector a
plt.quiver(0, 0, a[0], a[1], angles='xy', scale_units='xy', scale=1, color='blue', label='Vector a = (2, 3)')

# Plot the projection of b onto a
plt.quiver(0, 0, proj_ba[0], proj_ba[1], angles='xy', scale_units='xy', scale=1, color='red', label='Projection of b onto a')

# Mark the endpoint of the projection
plt.plot(proj_ba[0], proj_ba[1], 'ro')  # Point on the projection

# Add labels to the projection point
plt.text(proj_ba[0], proj_ba[1], ' P_{ba}', fontsize=12, color='red', verticalalignment='bottom')

# Add title and legend
plt.title('Vector Projection of b onto a')
plt.legend()
plt.axhline(0, color='black', linewidth=0.5, ls='--')
plt.axvline(0, color='black', linewidth=0.5, ls='--')

# Show the plot
plt.show()
